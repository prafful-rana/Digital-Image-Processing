# %%
import cv2
import copy
import matplotlib.pyplot as plt

img = cv2.imread('flowers.jpg',1)
m,n,z = img.shape
img2 = copy.deepcopy(img)

# %%
def imageCompliment(img):
    for i in range(m):
        for j in range(n):
            img[i,j]=255-img[i,j]
    return img
complimented = imageCompliment(img2)

# %%
plt.figure(figsize=(15,15))
plt.subplot(1, 2, 1)
plt.imshow(img)
plt.title("Original")

plt.subplot(1, 2, 2)
plt.imshow(imgCompli)
plt.title("Compliment")
plt.show()
